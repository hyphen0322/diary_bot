# %%
import os
os.environ["TRANSFORMERS_NO_TF"] = "1"
os.environ["TRANSFORMERS_NO_JAX"] = "1"

from transformers import AutoModelForSequenceClassification, AutoTokenizer
import torch
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 5
#       2 os.environ["TRANSFORMERS_NO_TF"] = "1"
#       3 os.environ["TRANSFORMERS_NO_JAX"] = "1"
# ----> 5 from transformers import AutoModelForSequenceClassification, AutoTokenizer
#       6 import torch
#
# File c:\Users\21T343\anaconda3\lib\site-packages\transformers\__init__.py:30
#      27 from typing import TYPE_CHECKING
#      29 # Check the dependencies satisfy the minimal versions required.
# ---> 30 from . import dependency_versions_check
#      31 from .utils import (
#      32     OptionalDependencyNotAvailable,
#      33     _LazyModule,
#    (...)
#      44     logging,
#      45 )
#      48 logger = logging.get_logger(__name__)  # pylint: disable=invalid-name
#
# File c:\Users\21T343\anaconda3\lib\site-packages\transformers\dependency_versions_check.py:17
#      14 import sys
#      16 from .dependency_versions_table import deps
# ---> 17 from .utils.versions import require_version, require_version_core
#      20 # define which module versions we always want to check at run time
#      21 # (usually the ones defined in `install_requires` in setup.py)
#      22 #
#      23 # order specific notes:
#      24 # - tqdm must be checked before tokenizers
#      26 pkgs_to_check_at_runtime = "python tqdm regex requests packaging filelock numpy tokenizers".split()
#
# File c:\Users\21T343\anaconda3\lib\site-packages\transformers\utils\__init__.py:34
#      25 from .constants import IMAGENET_DEFAULT_MEAN, IMAGENET_DEFAULT_STD, IMAGENET_STANDARD_MEAN, IMAGENET_STANDARD_STD
#      26 from .doc import (
#      27     add_code_sample_docstrings,
#      28     add_end_docstrings,
#    (...)
#      32     replace_return_docstrings,
#      33 )
# ---> 34 from .generic import (
#      35     ContextManagers,
#      36     ExplicitEnum,
#      37     ModelOutput,
#      38     PaddingStrategy,
#      39     TensorType,
#      40     cached_property,
#      41     expand_dims,
#      42     find_labels,
#      43     flatten_dict,
#      44     is_jax_tensor,
#      45     is_numpy_array,
#      46     is_tensor,
#      47     is_tf_tensor,
#      48     is_torch_device,
#      49     is_torch_tensor,
#      50     reshape,
#      51     squeeze,
#      52     tensor_size,
#      53     to_numpy,
#      54     to_py_obj,
#      55     transpose,
#      56     working_or_temp_dir,
#      57 )
#      58 from .hub import (
#      59     CLOUDFRONT_DISTRIB_PREFIX,
#      60     DISABLE_TELEMETRY,
#    (...)
#      86     send_example_telemetry,
#      87 )
#      88 from .import_utils import (
#      89     ENV_VARS_TRUE_AND_AUTO_VALUES,
#      90     ENV_VARS_TRUE_VALUES,
#    (...)
#     163     torch_version,
#     164 )
#
# File c:\Users\21T343\anaconda3\lib\site-packages\transformers\utils\generic.py:33
#      29 from .import_utils import is_flax_available, is_tf_available, is_torch_available, is_torch_fx_proxy
#      32 if is_tf_available():
# ---> 33     import tensorflow as tf
#      35 if is_flax_available():
#      36     import jax.numpy as jnp
#
# File c:\Users\21T343\anaconda3\lib\site-packages\tensorflow\__init__.py:45
#      42 from tensorflow.python import tf2 as _tf2
#      43 _tf2.enable()
# ---> 45 from ._api.v2 import __internal__
#      46 from ._api.v2 import __operators__
#      47 from ._api.v2 import audio
#
# File c:\Users\21T343\anaconda3\lib\site-packages\tensorflow\_api\v2\__internal__\__init__.py:11
#       9 from . import decorator
#      10 from . import dispatch
# ---> 11 from . import distribute
#      12 from . import eager_context
#      13 from . import feature_column
#
# File c:\Users\21T343\anaconda3\lib\site-packages\tensorflow\_api\v2\__internal__\distribute\__init__.py:11
#       9 from . import interim
#      10 from . import multi_process_runner
# ---> 11 from tensorflow.python.distribute.distribution_strategy_context import variable_sync_on_read_context
#      12 from tensorflow.python.distribute.merge_call_interim import strategy_supports_no_merge_call
#      13 from tensorflow.python.distribute.sharded_variable import ShardedVariable
#
# ModuleNotFoundError: No module named 'tensorflow.python.distribute.distribution_strategy_context'

# %%
# !pip install --upgrade tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users
#    --- ------------------------------------ 34.6/375.7 MB 5.5 MB/s eta 0:01:02
#    --- ------------------------------------ 35.7/375.7 MB 5.5 MB/s eta 0:01:02
#    --- ------------------------------------ 36.7/375.7 MB 5.5 MB/s eta 0:01:02
#    ---- ----------------------------------- 38.3/375.7 MB 5.6 MB/s eta 0:01:01
#    ---- ----------------------------------- 39.6/375.7 MB 5.6 MB/s eta 0:01:00
#    ---- ----------------------------------- 40.9/375.7 MB 5.6 MB/s eta 0:01:00
#    ---- ----------------------------------- 42.2/375.7 MB 5.6 MB/s eta 0:01:00
#    ---- ----------------------------------- 43.3/375.7 MB 5.6 MB/s eta 0:01:00
#    ---- ----------------------------------- 44.6/375.7 MB 5.6 MB/s eta 0:00:59
#    ---- ----------------------------------- 46.1/375.7 MB 5.7 MB/s eta 0:00:59
#    ---- ----------------------------------- 46.9/375.7 MB 5.6 MB/s eta 0:00:59
#    ----- ---------------------------------- 48.0/375.7 MB 5.6 MB/s eta 0:00:59
#    ----- ---------------------------------- 49.3/375.7 MB 5.6 MB/s eta 0:00:59
#    ----- ---------------------------------- 50.6/375.7 MB 5.6 MB/s eta 0:00:58
#    ----- ---------------------------------- 51.6/375.7 MB 5.6 MB/s eta 0:00:58
#    ----- ---------------------------------- 52.4/375.7 MB 5.6 MB/s eta 0:00:59
#    ----- ---------------------------------- 53.5/375.7 MB 5.6 MB/s eta 0:00:58
#    ----- ---------------------------------- 54.8/375.7 MB 5.5 MB/s eta 0:00:58
#    ----- ---------------------------------- 55.6/375.7 MB 5.5 MB/s eta 0:00:59
#    ------ --------------------------------- 56.6/375.7 MB 5.5 MB/s eta 0:00:59
#    ------ --------------------------------- 57.7/375.7 MB 5.5 MB/s eta 0:00:59
#    ------ --------------------------------- 59.0/375.7 MB 5.5 MB/s eta 0:00:58
#    ------ --------------------------------- 60.0/375.7 MB 5.5 MB/s eta 0:00:58
#    ------ --------------------------------- 61.1/375.7 MB 5.5 MB/s eta 0:00:58
#    ------ --------------------------------- 61.9/375.7 MB 5.4 MB/s eta 0:00:58
#    ------ --------------------------------- 62.9/375.7 MB 5.4 MB/s eta 0:00:58
#    ------ --------------------------------- 63.7/375.7 MB 5.4 MB/s eta 0:00:58
# WARNING: Ignoring invalid distribution -cikit-learn (c:\users\21t343\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ecab-python3 (c:\users\21t343\anaconda3\lib\site-packages)
# ERROR: Exception:
# Traceback (most recent call last):
#   File "C:\Users\21T343\anaconda3\lib\site-packages\pip\_vendor\urllib3\response.py", line 438, in _error_catcher
#     yield
#   File "C:\Users\21T343\anaconda3\lib\site-packages\pip\_vendor\urllib3\response.py", line 561, in read
#     data = self._fp_read(amt) if not fp_closed else b""
#   File "C:\Users\21T343\anaconda3\lib\site-packages\pip\_vendor\urllib3\response.py", line 527, in _fp_read
#     return self._fp.read(amt) if amt is not None else self._fp.read()
#   File "C:\Users\21T343\anaconda3\lib\site-packages\pip\_vendor\cachecontrol\filewrapper.py", line 102, in read
#     self.__buf.write(data)
#   File "C:\Users\21T343\anaconda3\lib\tempfile.py", line 483, in func_wrapper
#     return func(*args, **kwargs)
# OSError: [Errno 28] No space left on device
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\21T343\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 105, in _run_wrapper
#     status = _inner_run()
#   File "C:\Users\21T343\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 96, in _inner_run
#     return self.run(options, args)
#   File "C:\Users\21T343\anaconda3\lib\site-packages\pip\_internal\cli\req_command.py", line 68, in wrapper
#     return func(self, options, args)
#   File "C:\Users\21T343\anaconda3\lib\site-packages\pip\_internal\commands\install.py", line 387, in run
#     requirement_set = resolver.resolve(
#   File "C:\Users\21T343\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\resolver.py", line 182, in resolve
#     self.factory.preparer.prepare_linked_requirements_more(reqs)
#   File "C:\Users\21T343\anaconda3\lib\site-packages\pip\_internal\operations\prepare.py", line 559, in prepare_linked_requirements_more
#     self._complete_partial_requirements(
#   File "C:\Users\21T343\anaconda3\lib\site-packages\pip\_internal\operations\prepare.py", line 474, in _complete_partial_requirements
#     for link, (filepath, _) in batch_download:
#   File "C:\Users\21T343\anaconda3\lib\site-packages\pip\_internal\network\download.py", line 313, in __call__
#     filepath, content_type = self._downloader(link, location)
#   File "C:\Users\21T343\anaconda3\lib\site-packages\pip\_internal\network\download.py", line 185, in __call__
#     bytes_received = self._process_response(
#   File "C:\Users\21T343\anaconda3\lib\site-packages\pip\_internal\network\download.py", line 208, in _process_response
#     return self._write_chunks_to_file(
#   File "C:\Users\21T343\anaconda3\lib\site-packages\pip\_internal\network\download.py", line 218, in _write_chunks_to_file
#     for chunk in chunks:
#   File "C:\Users\21T343\anaconda3\lib\site-packages\pip\_internal\cli\progress_bars.py", line 61, in _rich_download_progress_bar
#     for chunk in iterable:
#   File "C:\Users\21T343\anaconda3\lib\site-packages\pip\_internal\network\utils.py", line 65, in response_chunks
#     for chunk in response.raw.stream(
#   File "C:\Users\21T343\anaconda3\lib\site-packages\pip\_vendor\urllib3\response.py", line 622, in stream
#     data = self.read(amt=amt, decode_content=decode_content)
#   File "C:\Users\21T343\anaconda3\lib\site-packages\pip\_vendor\urllib3\response.py", line 560, in read
#     with self._error_catcher():
#   File "C:\Users\21T343\anaconda3\lib\contextlib.py", line 153, in __exit__
#     self.gen.throw(typ, value, traceback)
#   File "C:\Users\21T343\anaconda3\lib\site-packages\pip\_vendor\urllib3\response.py", line 455, in _error_catcher
#     raise ProtocolError("Connection broken: %r" % e, e)
# pip._vendor.urllib3.exceptions.ProtocolError: ("Connection broken: OSError(28, 'No space left on device')", OSError(28, 'No space left on device'))

# %%
import os
# TensorFlowとJAXのロードを無効化
os.environ["TRANSFORMERS_NO_TF"] = "1"
os.environ["TRANSFORMERS_NO_JAX"] = "1"

from transformers import AutoModelForSequenceClassification, AutoTokenizer
import torch

# ... 続くコード
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 6
#       3 os.environ["TRANSFORMERS_NO_TF"] = "1"
#       4 os.environ["TRANSFORMERS_NO_JAX"] = "1"
# ----> 6 from transformers import AutoModelForSequenceClassification, AutoTokenizer
#       7 import torch
#
# File c:\Users\21T343\anaconda3\lib\site-packages\transformers\__init__.py:30
#      27 from typing import TYPE_CHECKING
#      29 # Check the dependencies satisfy the minimal versions required.
# ---> 30 from . import dependency_versions_check
#      31 from .utils import (
#      32     OptionalDependencyNotAvailable,
#      33     _LazyModule,
#    (...)
#      44     logging,
#      45 )
#      48 logger = logging.get_logger(__name__)  # pylint: disable=invalid-name
#
# File c:\Users\21T343\anaconda3\lib\site-packages\transformers\dependency_versions_check.py:36
#      33 if pkg in deps:
#      34     if pkg == "tokenizers":
#      35         # must be loaded here, or else tqdm check may fail
# ---> 36         from .utils import is_tokenizers_available
#      38         if not is_tokenizers_available():
#      39             continue  # not required, check version only if installed
#
# File c:\Users\21T343\anaconda3\lib\site-packages\transformers\utils\__init__.py:34
#      25 from .constants import IMAGENET_DEFAULT_MEAN, IMAGENET_DEFAULT_STD, IMAGENET_STANDARD_MEAN, IMAGENET_STANDARD_STD
#      26 from .doc import (
#      27     add_code_sample_docstrings,
#      28     add_end_docstrings,
#    (...)
#      32     replace_return_docstrings,
#      33 )
# ---> 34 from .generic import (
#      35     ContextManagers,
#      36     ExplicitEnum,
#      37     ModelOutput,
#      38     PaddingStrategy,
#      39     TensorType,
#      40     cached_property,
#      41     expand_dims,
#      42     find_labels,
#      43     flatten_dict,
#      44     is_jax_tensor,
#      45     is_numpy_array,
#      46     is_tensor,
#      47     is_tf_tensor,
#      48     is_torch_device,
#      49     is_torch_tensor,
#      50     reshape,
#      51     squeeze,
#      52     tensor_size,
#      53     to_numpy,
#      54     to_py_obj,
#      55     transpose,
#      56     working_or_temp_dir,
#      57 )
#      58 from .hub import (
#      59     CLOUDFRONT_DISTRIB_PREFIX,
#      60     DISABLE_TELEMETRY,
#    (...)
#      86     send_example_telemetry,
#      87 )
#      88 from .import_utils import (
#      89     ENV_VARS_TRUE_AND_AUTO_VALUES,
#      90     ENV_VARS_TRUE_VALUES,
#    (...)
#     163     torch_version,
#     164 )
#
# File c:\Users\21T343\anaconda3\lib\site-packages\transformers\utils\generic.py:33
#      29 from .import_utils import is_flax_available, is_tf_available, is_torch_available, is_torch_fx_proxy
#      32 if is_tf_available():
# ---> 33     import tensorflow as tf
#      35 if is_flax_available():
#      36     import jax.numpy as jnp
#
# File c:\Users\21T343\anaconda3\lib\site-packages\tensorflow\__init__.py:45
#      42 from tensorflow.python import tf2 as _tf2
#      43 _tf2.enable()
# ---> 45 from ._api.v2 import __internal__
#      46 from ._api.v2 import __operators__
#      47 from ._api.v2 import audio
#
# File c:\Users\21T343\anaconda3\lib\site-packages\tensorflow\_api\v2\__internal__\__init__.py:11
#       9 from . import decorator
#      10 from . import dispatch
# ---> 11 from . import distribute
#      12 from . import eager_context
#      13 from . import feature_column
#
# File c:\Users\21T343\anaconda3\lib\site-packages\tensorflow\_api\v2\__internal__\distribute\__init__.py:11
#       9 from . import interim
#      10 from . import multi_process_runner
# ---> 11 from tensorflow.python.distribute.distribution_strategy_context import variable_sync_on_read_context
#      12 from tensorflow.python.distribute.merge_call_interim import strategy_supports_no_merge_call
#      13 from tensorflow.python.distribute.sharded_variable import ShardedVariable
#
# ModuleNotFoundError: No module named 'tensorflow.python.distribute.distribution_strategy_context'
