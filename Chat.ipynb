# %%
# !pip install streamlit langchain langchain-google-genai
# Out:
# ...
#   Using cached packaging-23.2-py3-none-any.whl.metadata (3.2 kB)
# ...
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ----------------- ---------------------- 0.4/1.0 MB 9.2 MB/s eta 0:00:01
#    ------------------------------ --------- 0.8/1.0 MB 8.2 MB/s eta 0:00:01
#    ---------------------------------------  1.0/1.0 MB 9.0 MB/s eta 0:00:01
#    ---------------------------------------- 1.0/1.0 MB 6.4 MB/s eta 0:00:00
# ...
# Using cached packaging-23.2-py3-none-any.whl (53 kB)
# ...
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.6 MB 8.3 MB/s eta 0:00:01
#    ------- -------------------------------- 0.5/2.6 MB 5.9 MB/s eta 0:00:01
#    ------------ --------------------------- 0.8/2.6 MB 5.9 MB/s eta 0:00:01
#    ----------------- ---------------------- 1.1/2.6 MB 6.1 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.5/2.6 MB 6.3 MB/s eta 0:00:01
# ...
